# %%
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress

# %%
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload = '{"limit":2000,"offset":0,"geoJson":{"type":"Polygon","coordinates":[[[-94.32951884471989,38.996363264325836],[-94.64880900585229,38.996363264325836],[-94.64880900585229,39.080896419140764],[-94.32951884471989,39.080896419140764],[-94.32951884471989,38.996363264325836]]]},"projection":true,"propertyMap":{"toDate":"2020-12-11T23:59:59.999Z","fromDate":"2020-12-08T00:00:00.000Z","pageSize":"2000","parentIncidentTypeIds":"149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15","zoomLevel":"12","latitude":"39.03864248355025","longitude":"-94.48916392528609","days":"1,2,3,4,5,6,7","startHour":"0","endHour":"24","timezone":"+00:00","relativeDate":"custom","agencyIds":"47860,1279,957,165,118,undefined,undefined"}}'
response = requests.request("POST", url, data=payload, headers=headers)
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "navigation": {
#     "nextPagePath": {
#       "requestData": {
#         "limit": 2000,
#         "offset": 2000,
#         "geoJson": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 -94.32951884471989,
#                 38.996363264325836
#               ],
#               [
#                 -94.64880900585229,
#                 38.996363264325836
#               ],
#               [
#                 -94.64880900585229,
#                 39.080896419140764
#               ],
#               [
#                 -94.32951884471989,
#                 39.080896419140764
#               ],
#               [
#                 -94.32951884471989,
#                 38.996363264325836
#               ]
#             ]
#           ]
#         },
#         "projection": true,
#         "propertyMap": {
#           "toDate": "2020-12-12T06:59:59.000Z",
#           "fromDate": "2020-12-08T07:00:00.000Z",
#           "pageSize": "2000",
#           "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15",
#           "zoomLevel": "12",
#           "latitude": "39.03864248355025",
#           "longitude": "-94.48916392528609",
#           "days": "1,2,3,4,5,6,7",
#           "startHour": "0",
#           "endHour": "24",
#           "timezone": "+00:00",
#           "relativeDate": "custom",
#           "agencyIds": "79,1279,165,47860,957,,118,"
#         }
#       }
#     },
#     "previousPagePath": {
#       "requestData": {
#         "limit": 2000,
#         "offset": 0,
#         "geoJson": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 -94.32951884471989,
#                 38.996363264325836
#               ],
#               [
#                 -94.64880900585229,
#                 38.996363264325836
#               ],
#               [
#                 -94.64880900585229,
#                 39.080896419140764
#               ],
#               [
#                 -94.32951884471989,
#                 39.080896419140764
#               ],
#               [
#                 -94.32951884471989,
#                 38.996363264325836
#               ]
#             ]
#           ]
#         },
#         "projection": true,
#         "propertyMap": {
#           "toDate": "2020-12-12T06:59:59.000Z",
#           "fromDate": "2020-12-08T07:00:00.000Z",
#           "pageSize": "2000",
#           "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15",
#           "zoomLevel": "12",
#           "latitude": "39.03864248355025",
#           "longitude": "-94.48916392528609",
#           "days": "1,2,3,4,5,6,7",
#           "startHour": "0",
#           "endHour": "24",
#           "timezone": "+00:00",
#           "relativeDate": "custom",
#           "agencyIds": "79,1279,165,47860,957,,118,"
#         }
#       }
#     }
#   },
#   "result": {
#     "list": {
#       "incidents": [
#         {
#           "id": "5fd5cb93118ad7b37a1ed312",
#           "crapiId": "979454244",
#           "location": {
#             "coordinates": [
#               -94.55060999999999,
#               39.0462901
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Alcohol Influence Report",
#           "parentIncidentType": "Quality of Life",
#           "parentIncidentTypeId": 12,
#           "_id": "5fd5cb93118ad7b37a1ed312"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed304",
#           "crapiId": "979461882",
#           "location": {
#             "coordinates": [
#               -94.56781099999999,
#               39.017393
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd5cb93118ad7b37a1ed304"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed2fe",
#           "crapiId": "979463749",
#           "location": {
#             "coordinates": [
#               -94.5567811,
#               39.0335058
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd5cb93118ad7b37a1ed2fe"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c1ff",
#           "crapiId": "979513824",
#           "location": {
#             "coordinates": [
#               -94.56212359999999,
#               39.032097
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd6a0be118ad7b37a31c1ff"
#         },
#         {
#           "id": "5fd55657118ad7b37a03d877",
#           "crapiId": "979475860",
#           "location": {
#             "coordinates": [
#               -94.56708689999999,
#               39.0342456
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd55657118ad7b37a03d877"
#         },
#         {
#           "id": "5fda954d557b2b3e738fa70e",
#           "crapiId": "979652452",
#           "location": {
#             "coordinates": [
#               -94.5035979,
#               39.0313714
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fda954d557b2b3e738fa70e"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c2b9",
#           "crapiId": "979477063",
#           "location": {
#             "coordinates": [
#               -94.39044489999999,
#               39.0320894
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c2b9"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288c5",
#           "crapiId": "979449602",
#           "location": {
#             "coordinates": [
#               -94.5729411,
#               39.017268
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a0288c5"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288f8",
#           "crapiId": "979442480",
#           "location": {
#             "coordinates": [
#               -94.55468590000001,
#               39.0417145
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a0288f8"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61cdf9",
#           "crapiId": "979565340",
#           "location": {
#             "coordinates": [
#               -94.59503819999999,
#               39.041546
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd7f92a118ad7b37a61cdf9"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288cf",
#           "crapiId": "979443596",
#           "location": {
#             "coordinates": [
#               -94.5729411,
#               39.017268
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a0288cf"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c2a0",
#           "crapiId": "979478566",
#           "location": {
#             "coordinates": [
#               -94.5844534,
#               39.0657065
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c2a0"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61ce0b",
#           "crapiId": "979563443",
#           "location": {
#             "coordinates": [
#               -94.5374437,
#               39.0799187
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd7f92a118ad7b37a61ce0b"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed30f",
#           "crapiId": "979454249",
#           "location": {
#             "coordinates": [
#               -94.48729209999999,
#               39.012294
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd5cb93118ad7b37a1ed30f"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288ec",
#           "crapiId": "979442488",
#           "location": {
#             "coordinates": [
#               -94.56090220000002,
#               39.06240469999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Possession of Stolen Property",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd54bc9118ad7b37a0288ec"
#         },
#         {
#           "id": "5fdfded3830081894a064731",
#           "crapiId": "980214190",
#           "location": {
#             "coordinates": [
#               -94.518234,
#               39.0536931
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fdfded3830081894a064731"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288c4",
#           "crapiId": "979449603",
#           "location": {
#             "coordinates": [
#               -94.54822999999999,
#               39.069711
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a0288c4"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a02892e",
#           "crapiId": "979434485",
#           "location": {
#             "coordinates": [
#               -94.59183449999999,
#               39.0415092
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a02892e"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed2d5",
#           "crapiId": "979473637",
#           "location": {
#             "coordinates": [
#               -94.58148600000001,
#               39.008367
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd5cb93118ad7b37a1ed2d5"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028928",
#           "crapiId": "979434491",
#           "location": {
#             "coordinates": [
#               -94.4429715,
#               39.04493799999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a028928"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed30e",
#           "crapiId": "979454250",
#           "location": {
#             "coordinates": [
#               -94.47484610000001,
#               39.0438641
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd5cb93118ad7b37a1ed30e"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c296",
#           "crapiId": "979478577",
#           "location": {
#             "coordinates": [
#               -94.5168121,
#               39.0156421
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd6a0be118ad7b37a31c296"
#         },
#         {
#           "id": "5fde923b830081894ad6c7e6",
#           "crapiId": "980148656",
#           "location": {
#             "coordinates": [
#               -94.5207532,
#               39.03490499999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fde923b830081894ad6c7e6"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c26b",
#           "crapiId": "979485406",
#           "location": {
#             "coordinates": [
#               -94.600759,
#               39.0766304
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd6a0be118ad7b37a31c26b"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c295",
#           "crapiId": "979478578",
#           "location": {
#             "coordinates": [
#               -94.5942817,
#               39.0390281
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c295"
#         },
#         {
#           "id": "5fdfded3830081894a064722",
#           "crapiId": "980219659",
#           "location": {
#             "coordinates": [
#               -94.5832159,
#               39.07387000000001
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fdfded3830081894a064722"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288c2",
#           "crapiId": "979449607",
#           "location": {
#             "coordinates": [
#               -94.59154509999999,
#               39.0531397
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a0288c2"
#         },
#         {
#           "id": "5fd943d3557b2b3e735d8612",
#           "crapiId": "979612245",
#           "location": {
#             "coordinates": [
#               -94.58634599999999,
#               39.037659
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd943d3557b2b3e735d8612"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028938",
#           "crapiId": "979431166",
#           "location": {
#             "coordinates": [
#               -94.5909181,
#               39.0533716
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a028938"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028952",
#           "crapiId": "979428417",
#           "location": {
#             "coordinates": [
#               -94.5864199,
#               39.0560131
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Robbery (Strong Armed Street)",
#           "parentIncidentType": "Robbery",
#           "parentIncidentTypeId": 98,
#           "_id": "5fd54bc9118ad7b37a028952"
#         },
#         {
#           "id": "5fe3d094830081894a95df23",
#           "crapiId": "980368306",
#           "location": {
#             "coordinates": [
#               -94.5771358,
#               39.0649706
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fe3d094830081894a95df23"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61cdd2",
#           "crapiId": "979569582",
#           "location": {
#             "coordinates": [
#               -94.4897543,
#               39.0086427
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd7f92a118ad7b37a61cdd2"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028963",
#           "crapiId": "979425834",
#           "location": {
#             "coordinates": [
#               -94.5246767,
#               39.0477965
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a028963"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028937",
#           "crapiId": "979431170",
#           "location": {
#             "coordinates": [
#               -94.589213,
#               39.0421953
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd54bc9118ad7b37a028937"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61ce8c",
#           "crapiId": "979535007",
#           "location": {
#             "coordinates": [
#               -94.5207532,
#               39.03490499999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd7f92a118ad7b37a61ce8c"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000cb",
#           "crapiId": "979420927",
#           "location": {
#             "coordinates": [
#               -94.554011,
#               39.069085
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd479e7118ad7b37af000cb"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a02895d",
#           "crapiId": "979425842",
#           "location": {
#             "coordinates": [
#               -94.554011,
#               39.069085
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd54bc9118ad7b37a02895d"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028944",
#           "crapiId": "979428428",
#           "location": {
#             "coordinates": [
#               -94.55301299999999,
#               39.066236
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd54bc9118ad7b37a028944"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000c7",
#           "crapiId": "979420933",
#           "location": {
#             "coordinates": [
#               -94.5703219,
#               39.0629042
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd479e7118ad7b37af000c7"
#         },
#         {
#           "id": "5febbab4830081894ab402e4",
#           "crapiId": "980721769",
#           "location": {
#             "coordinates": [
#               -94.498206,
#               39.0024631
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5febbab4830081894ab402e4"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000d5",
#           "crapiId": "979419284",
#           "location": {
#             "coordinates": [
#               -94.58537679999999,
#               39.0628784
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd479e7118ad7b37af000d5"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000e1",
#           "crapiId": "979417141",
#           "location": {
#             "coordinates": [
#               -94.39566719999999,
#               39.0353071
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd479e7118ad7b37af000e1"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c2a7",
#           "crapiId": "979477075",
#           "location": {
#             "coordinates": [
#               -94.5580906,
#               39.0088034
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c2a7"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028903",
#           "crapiId": "979440314",
#           "location": {
#             "coordinates": [
#               -94.58886539999999,
#               39.0417862
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd54bc9118ad7b37a028903"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed2ee",
#           "crapiId": "979466062",
#           "location": {
#             "coordinates": [
#               -94.58642499999999,
#               39.01415859999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd5cb93118ad7b37a1ed2ee"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000ec",
#           "crapiId": "979414541",
#           "location": {
#             "coordinates": [
#               -94.58465559999999,
#               39.078247
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd479e7118ad7b37af000ec"
#         },
#         {
#           "id": "5fd404a4118ad7b37ad510eb",
#           "crapiId": "979407421",
#           "location": {
#             "coordinates": [
#               -94.5654852,
#               39.0546597
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd404a4118ad7b37ad510eb"
#         },
#         {
#           "id": "5fd404a4118ad7b37ad510e8",
#           "crapiId": "979409175",
#           "location": {
#             "coordinates": [
#               -94.5617575,
#               39.0197577
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd404a4118ad7b37ad510e8"
#         },
#         {
#           "id": "5fda954d557b2b3e738fa65b",
#           "crapiId": "979696751",
#           "location": {
#             "coordinates": [
#               -94.41679429999999,
#               39.0275279
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Sodomy",
#           "parentIncidentType": "Sexual Offense",
#           "parentIncidentTypeId": 8,
#           "_id": "5fda954d557b2b3e738fa65b"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000c5",
#           "crapiId": "979423116",
#           "location": {
#             "coordinates": [
#               -94.3910073,
#               39.03166179999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd479e7118ad7b37af000c5"
#         },
#         {
#           "id": "5fd479e7118ad7b37af00107",
#           "crapiId": "979407424",
#           "location": {
#             "coordinates": [
#               -94.4950465,
#               39.0298004
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd479e7118ad7b37af00107"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028961",
#           "crapiId": "979425838",
#           "location": {
#             "coordinates": [
#               -94.4415844,
#               39.0177802
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd54bc9118ad7b37a028961"
#         },
#         {
#           "id": "5fdd39f0830081894aa6c7c9",
#           "crapiId": "980081793",
#           "location": {
#             "coordinates": [
#               -94.52016669999999,
#               39.0726691
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fdd39f0830081894aa6c7c9"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028950",
#           "crapiId": "979428418",
#           "location": {
#             "coordinates": [
#               -94.5380479,
#               38.9995206
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd54bc9118ad7b37a028950"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c71a",
#           "crapiId": "979400650",
#           "location": {
#             "coordinates": [
#               -94.5287038,
#               39.0401236
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd3fa43118ad7b37ad3c71a"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c732",
#           "crapiId": "979391262",
#           "location": {
#             "coordinates": [
#               -94.5560155,
#               39.0064247
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd3fa43118ad7b37ad3c732"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c731",
#           "crapiId": "979391263",
#           "location": {
#             "coordinates": [
#               -94.5932387,
#               38.9979954
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd3fa43118ad7b37ad3c731"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028902",
#           "crapiId": "979440316",
#           "location": {
#             "coordinates": [
#               -94.56804729999999,
#               39.0778411
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a028902"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c273",
#           "crapiId": "979484084",
#           "location": {
#             "coordinates": [
#               -94.6009607,
#               39.0451025
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c273"
#         },
#         {
#           "id": "5fd479e7118ad7b37af00106",
#           "crapiId": "979407425",
#           "location": {
#             "coordinates": [
#               -94.5504957,
#               39.0320846
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd479e7118ad7b37af00106"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c73d",
#           "crapiId": "979389156",
#           "location": {
#             "coordinates": [
#               -94.60342059999999,
#               39.0506528
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd3fa43118ad7b37ad3c73d"
#         },
#         {
#           "id": "5fd5cb93118ad7b37a1ed2ea",
#           "crapiId": "979466674",
#           "location": {
#             "coordinates": [
#               -94.5424895,
#               39.0367464
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd5cb93118ad7b37a1ed2ea"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c71f",
#           "crapiId": "979400645",
#           "location": {
#             "coordinates": [
#               -94.59126309999999,
#               39.0370529
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd3fa43118ad7b37ad3c71f"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c72c",
#           "crapiId": "979391270",
#           "location": {
#             "coordinates": [
#               -94.5809585,
#               39.0606082
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd3fa43118ad7b37ad3c72c"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c716",
#           "crapiId": "979400655",
#           "location": {
#             "coordinates": [
#               -94.5162611,
#               39.0717642
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd3fa43118ad7b37ad3c716"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028940",
#           "crapiId": "979431162",
#           "location": {
#             "coordinates": [
#               -94.38923989999999,
#               39.0320533
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd54bc9118ad7b37a028940"
#         },
#         {
#           "id": "5fdd39f0830081894aa6c7ca",
#           "crapiId": "980081792",
#           "location": {
#             "coordinates": [
#               -94.41679429999999,
#               39.0275279
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Rape",
#           "parentIncidentType": "Sexual Offense",
#           "parentIncidentTypeId": 8,
#           "_id": "5fdd39f0830081894aa6c7ca"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028939",
#           "crapiId": "979431165",
#           "location": {
#             "coordinates": [
#               -94.55408150000001,
#               39.05112340000001
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd54bc9118ad7b37a028939"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a028966",
#           "crapiId": "979425831",
#           "location": {
#             "coordinates": [
#               -94.59010420000001,
#               39.057375
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Fraudulent Use of a Credit Device",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd54bc9118ad7b37a028966"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c739",
#           "crapiId": "979389162",
#           "location": {
#             "coordinates": [
#               -94.5995564,
#               39.0479663
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Robbery (Armed Street)",
#           "parentIncidentType": "Robbery",
#           "parentIncidentTypeId": 98,
#           "_id": "5fd3fa43118ad7b37ad3c739"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61cdc7",
#           "crapiId": "979572445",
#           "location": {
#             "coordinates": [
#               -94.5508784,
#               39.0682075
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Non-Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd7f92a118ad7b37a61cdc7"
#         },
#         {
#           "id": "5fe12d6f830081894a369172",
#           "crapiId": "980257484",
#           "location": {
#             "coordinates": [
#               -94.58840049999999,
#               39.0398065
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fe12d6f830081894a369172"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c737",
#           "crapiId": "979389166",
#           "location": {
#             "coordinates": [
#               -94.5875135,
#               39.0389474
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Non-Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd3fa43118ad7b37ad3c737"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c711",
#           "crapiId": "979400661",
#           "location": {
#             "coordinates": [
#               -94.5339395,
#               39.060722
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd3fa43118ad7b37ad3c711"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c759",
#           "crapiId": "979385751",
#           "location": {
#             "coordinates": [
#               -94.57396890000001,
#               39.013793
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd3fa43118ad7b37ad3c759"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c725",
#           "crapiId": "979391276",
#           "location": {
#             "coordinates": [
#               -94.5650016,
#               39.0624373
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd3fa43118ad7b37ad3c725"
#         },
#         {
#           "id": "5fd943d3557b2b3e735d8684",
#           "crapiId": "979578312",
#           "location": {
#             "coordinates": [
#               -94.59057729999999,
#               39.0542296
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd943d3557b2b3e735d8684"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c771",
#           "crapiId": "979380595",
#           "location": {
#             "coordinates": [
#               -94.4837785,
#               39.0377922
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd3fa43118ad7b37ad3c771"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c26f",
#           "crapiId": "979484087",
#           "location": {
#             "coordinates": [
#               -94.50178,
#               39.02661
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd6a0be118ad7b37a31c26f"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000c2",
#           "crapiId": "979423123",
#           "location": {
#             "coordinates": [
#               -94.554565,
#               39.0502514
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd479e7118ad7b37af000c2"
#         },
#         {
#           "id": "5fd943d3557b2b3e735d8619",
#           "crapiId": "979609692",
#           "location": {
#             "coordinates": [
#               -94.5925223,
#               39.04206980000001
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd943d3557b2b3e735d8619"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c758",
#           "crapiId": "979385753",
#           "location": {
#             "coordinates": [
#               -94.58162999999999,
#               39.048099
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Other",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd3fa43118ad7b37ad3c758"
#         },
#         {
#           "id": "5fd2b352118ad7b37aa66724",
#           "crapiId": "979374665",
#           "location": {
#             "coordinates": [
#               -94.5804586,
#               39.0685951
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Robbery (Armed Street)",
#           "parentIncidentType": "Robbery",
#           "parentIncidentTypeId": 98,
#           "_id": "5fd2b352118ad7b37aa66724"
#         },
#         {
#           "id": "5fd6a0be118ad7b37a31c28a",
#           "crapiId": "979480819",
#           "location": {
#             "coordinates": [
#               -94.5877151,
#               39.0705847
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd6a0be118ad7b37a31c28a"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b5a",
#           "crapiId": "979370448",
#           "location": {
#             "coordinates": [
#               -94.5604479,
#               39.0301117
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd328c7118ad7b37ac13b5a"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c74d",
#           "crapiId": "979387447",
#           "location": {
#             "coordinates": [
#               -94.5472727,
#               39.0749476
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd3fa43118ad7b37ad3c74d"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b77",
#           "crapiId": "979365010",
#           "location": {
#             "coordinates": [
#               -94.5713304,
#               39.0704944
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd328c7118ad7b37ac13b77"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c76b",
#           "crapiId": "979383777",
#           "location": {
#             "coordinates": [
#               -94.55160359999999,
#               39.0762207
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd3fa43118ad7b37ad3c76b"
#         },
#         {
#           "id": "5fd479e7118ad7b37af000bf",
#           "crapiId": "979423126",
#           "location": {
#             "coordinates": [
#               -94.57552079999999,
#               39.0528048
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd479e7118ad7b37af000bf"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b82",
#           "crapiId": "979360740",
#           "location": {
#             "coordinates": [
#               -94.5774555,
#               39.0493977
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd328c7118ad7b37ac13b82"
#         },
#         {
#           "id": "5fd2b352118ad7b37aa6671d",
#           "crapiId": "979374674",
#           "location": {
#             "coordinates": [
#               -94.5007141,
#               39.0603044
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd2b352118ad7b37aa6671d"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b8c",
#           "crapiId": "979355641",
#           "location": {
#             "coordinates": [
#               -94.44751529999999,
#               39.0430991
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd328c7118ad7b37ac13b8c"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c778",
#           "crapiId": "979378920",
#           "location": {
#             "coordinates": [
#               -94.5790169,
#               39.0640069
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Non-Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd3fa43118ad7b37ad3c778"
#         },
#         {
#           "id": "5fd2b352118ad7b37aa66736",
#           "crapiId": "979356930",
#           "location": {
#             "coordinates": [
#               -94.5435765,
#               39.0536957
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd2b352118ad7b37aa66736"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b80",
#           "crapiId": "979360741",
#           "location": {
#             "coordinates": [
#               -94.5944227,
#               39.0431185
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Non-Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd328c7118ad7b37ac13b80"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b9f",
#           "crapiId": "979352169",
#           "location": {
#             "coordinates": [
#               -94.54014339999999,
#               39.0477398
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Possession/Sale/Distribution of a Controlled Substance",
#           "parentIncidentType": "Quality of Life",
#           "parentIncidentTypeId": 12,
#           "_id": "5fd328c7118ad7b37ac13b9f"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b9c",
#           "crapiId": "979352173",
#           "location": {
#             "coordinates": [
#               -94.5430369,
#               38.999578
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd328c7118ad7b37ac13b9c"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13ba0",
#           "crapiId": "979350089",
#           "location": {
#             "coordinates": [
#               -94.5586082,
#               39.0592332
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd328c7118ad7b37ac13ba0"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13ba7",
#           "crapiId": "979346146",
#           "location": {
#             "coordinates": [
#               -94.55311449999999,
#               38.9988941
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd328c7118ad7b37ac13ba7"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13bb6",
#           "crapiId": "979342128",
#           "location": {
#             "coordinates": [
#               -94.5647396,
#               39.0744087
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Robbery (Armed Street)",
#           "parentIncidentType": "Robbery",
#           "parentIncidentTypeId": 98,
#           "_id": "5fd328c7118ad7b37ac13bb6"
#         },
# ...
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd15af3118ad7b37a761345"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761327",
#           "crapiId": "979265171",
#           "location": {
#             "coordinates": [
#               -94.5834014,
#               39.0668145
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd15af3118ad7b37a761327"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761329",
#           "crapiId": "979265169",
#           "location": {
#             "coordinates": [
#               -94.5877957,
#               39.0548218
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Fraud / Stealing Through Deceit (Scam/Confidence Game)",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd15af3118ad7b37a761329"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76132f",
#           "crapiId": "979262554",
#           "location": {
#             "coordinates": [
#               -94.5389057,
#               39.0232202
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd15af3118ad7b37a76132f"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76132d",
#           "crapiId": "979262555",
#           "location": {
#             "coordinates": [
#               -94.5589368,
#               39.0678934
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd15af3118ad7b37a76132d"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76135c",
#           "crapiId": "979256337",
#           "location": {
#             "coordinates": [
#               -94.5717521,
#               39.0688548
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Obstructing and Resisting an Officer",
#           "parentIncidentType": "Quality of Life",
#           "parentIncidentTypeId": 12,
#           "_id": "5fd15af3118ad7b37a76135c"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d252",
#           "crapiId": "979251552",
#           "location": {
#             "coordinates": [
#               -94.547338,
#               39.066064
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Other",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd0860a118ad7b37a62d252"
#         },
#         {
#           "id": "5fd328c7118ad7b37ac13b79",
#           "crapiId": "979365006",
#           "location": {
#             "coordinates": [
#               -94.55339649999999,
#               39.0695513
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Embezzlement",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd328c7118ad7b37ac13b79"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76135b",
#           "crapiId": "979256338",
#           "location": {
#             "coordinates": [
#               -94.5838663,
#               39.0137525
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd15af3118ad7b37a76135b"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761253",
#           "crapiId": "979311537",
#           "location": {
#             "coordinates": [
#               -94.59217029999999,
#               39.061129
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd15af3118ad7b37a761253"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761357",
#           "crapiId": "979256340",
#           "location": {
#             "coordinates": [
#               -94.5901394,
#               39.0420928
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd15af3118ad7b37a761357"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76135a",
#           "crapiId": "979256339",
#           "location": {
#             "coordinates": [
#               -94.58271610000001,
#               39.06395759999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd15af3118ad7b37a76135a"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288cd",
#           "crapiId": "979443599",
#           "location": {
#             "coordinates": [
#               -94.59749269999999,
#               39.038088
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd54bc9118ad7b37a0288cd"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761366",
#           "crapiId": "979256326",
#           "location": {
#             "coordinates": [
#               -94.50869209999999,
#               39.0221214
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Auto Part or Accessory)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd15af3118ad7b37a761366"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761301",
#           "crapiId": "979268862",
#           "location": {
#             "coordinates": [
#               -94.54409009999999,
#               39.0674766
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd15af3118ad7b37a761301"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761337",
#           "crapiId": "979261242",
#           "location": {
#             "coordinates": [
#               -94.59434759999999,
#               39.0408121
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd15af3118ad7b37a761337"
#         },
#         {
#           "id": "5fd2a8b8118ad7b37aa4fb90",
#           "crapiId": "979314428",
#           "location": {
#             "coordinates": [
#               -94.60394409999999,
#               39.0613468
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd2a8b8118ad7b37aa4fb90"
#         },
#         {
#           "id": "5fd15af3118ad7b37a761353",
#           "crapiId": "979256344",
#           "location": {
#             "coordinates": [
#               -94.5625433,
#               39.0365726
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd15af3118ad7b37a761353"
#         },
#         {
#           "id": "5fd54bc9118ad7b37a0288c0",
#           "crapiId": "979449610",
#           "location": {
#             "coordinates": [
#               -94.4429715,
#               39.04493799999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd54bc9118ad7b37a0288c0"
#         },
#         {
#           "id": "5fdbe74f557b2b3e73beec59",
#           "crapiId": "980040227",
#           "location": {
#             "coordinates": [
#               -94.592896,
#               39.0146971
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fdbe74f557b2b3e73beec59"
#         },
#         {
#           "id": "5fd3fa43118ad7b37ad3c77d",
#           "crapiId": "979377343",
#           "location": {
#             "coordinates": [
#               -94.4429715,
#               39.04493799999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Shoplift",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd3fa43118ad7b37ad3c77d"
#         },
#         {
#           "id": "5fd7f92a118ad7b37a61cdee",
#           "crapiId": "979568886",
#           "location": {
#             "coordinates": [
#               -94.55158349999999,
#               39.0176138
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing - Other",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd7f92a118ad7b37a61cdee"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d28a",
#           "crapiId": "979241048",
#           "location": {
#             "coordinates": [
#               -94.5423223,
#               39.01193079999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd0860a118ad7b37a62d28a"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76134f",
#           "crapiId": "979256349",
#           "location": {
#             "coordinates": [
#               -94.5800555,
#               39.06381820000001
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Robbery (Strong Armed Street)",
#           "parentIncidentType": "Robbery",
#           "parentIncidentTypeId": 98,
#           "_id": "5fd15af3118ad7b37a76134f"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d288",
#           "crapiId": "979241050",
#           "location": {
#             "coordinates": [
#               -94.5215138,
#               39.066382
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd0860a118ad7b37a62d288"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d286",
#           "crapiId": "979241052",
#           "location": {
#             "coordinates": [
#               -94.605921,
#               39.0139407
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Auto (Theft from Auto)",
#           "parentIncidentType": "Theft from Vehicle",
#           "parentIncidentTypeId": 101,
#           "_id": "5fd0860a118ad7b37a62d286"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d26c",
#           "crapiId": "979247660",
#           "location": {
#             "coordinates": [
#               -94.5417537,
#               39.0797512
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd0860a118ad7b37a62d26c"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d275",
#           "crapiId": "979243845",
#           "location": {
#             "coordinates": [
#               -94.5861254,
#               39.0488234
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stealing from Building/Residence",
#           "parentIncidentType": "Theft",
#           "parentIncidentTypeId": 103,
#           "_id": "5fd0860a118ad7b37a62d275"
#         },
#         {
#           "id": "5fd15af3118ad7b37a76134c",
#           "crapiId": "979256352",
#           "location": {
#             "coordinates": [
#               -94.5320868,
#               39.0351568
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Burglary (Non-Residential)",
#           "parentIncidentType": "Breaking & Entering",
#           "parentIncidentTypeId": 100,
#           "_id": "5fd15af3118ad7b37a76134c"
#         },
#         {
#           "id": "5fd005ea118ad7b37a462780",
#           "crapiId": "979228957",
#           "location": {
#             "coordinates": [
#               -94.55191219999999,
#               39.0388536
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd005ea118ad7b37a462780"
#         },
#         {
#           "id": "5fd005ea118ad7b37a46277e",
#           "crapiId": "979228959",
#           "location": {
#             "coordinates": [
#               -94.57243220000001,
#               39.0780958
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd005ea118ad7b37a46277e"
#         },
#         {
#           "id": "5fd005ea118ad7b37a462783",
#           "crapiId": "979228236",
#           "location": {
#             "coordinates": [
#               -94.53235049999999,
#               39.0690551
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd005ea118ad7b37a462783"
#         },
#         {
#           "id": "5fd005ea118ad7b37a462784",
#           "crapiId": "979228235",
#           "location": {
#             "coordinates": [
#               -94.546509,
#               39.0189544
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd005ea118ad7b37a462784"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d257",
#           "crapiId": "979249210",
#           "location": {
#             "coordinates": [
#               -94.4949707,
#               39.0075441
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Property Damage",
#           "parentIncidentType": "Property Crime",
#           "parentIncidentTypeId": 180,
#           "_id": "5fd0860a118ad7b37a62d257"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d2a5",
#           "crapiId": "979231239",
#           "location": {
#             "coordinates": [
#               -94.58271610000001,
#               39.06395759999999
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Domestic Violence Assault (Non-Aggravated)",
#           "parentIncidentType": "Assault",
#           "parentIncidentTypeId": 149,
#           "_id": "5fd0860a118ad7b37a62d2a5"
#         },
#         {
#           "id": "5fd0860a118ad7b37a62d284",
#           "crapiId": "979241054",
#           "location": {
#             "coordinates": [
#               -94.4912634,
#               39.032303
#             ],
#             "type": "Point"
#           },
#           "incidentType": "Stolen Auto",
#           "parentIncidentType": "Theft of Vehicle",
#           "parentIncidentTypeId": 99,
#           "_id": "5fd0860a118ad7b37a62d284"
#         }
#       ],
#       "timeZone": "America/Chicago"
#     }
#   }
# }

# %%
payload = {}
from_date = "2020-3-1T00:00:00.000Z"
to_date = "2020-12-31T23:59:59.999Z"
pageSize = "100000"
payload["limit"] = pageSize
payload["offset"] = 0
payload["geoJson"] = {"type": "Polygon", "coordinates": [[[-94.32951884471989, 38.996363264325836], [-94.64880900585229, 38.996363264325836], [-94.64880900585229, 39.080896419140764], [-94.32951884471989, 39.080896419140764], [-94.32951884471989, 38.996363264325836]]]}
payload["projection"]= "true"
payload["propertyMap"] = {"toDate": to_date, "fromDate": from_date, "pageSize": pageSize, "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15", "zoomLevel": "12", "latitude": "39.03864248355025", "longitude": "-94.48916392528609", "days": "1,2,3,4,5,6,7", "startHour": "0", "endHour": "24", "timezone": "+00:00", "relativeDate": "custom", "agencyIds": "47860,1279,957,165,118,undefined,undefined"}
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload  = json.dumps(payload)
response = requests.request("POST", url, data=payload, headers=headers)
print(len(response.json()['result']['list']['incidents']))
# Out:
# 15200

# %%
crime_df = pd.DataFrame(response.json()['result']['list']['incidents'])
crime_df.head()
# Out:
#                          id    crapiId  \
# 0  5fefaddb830081894a44e56a  980874097
# 1  5fefaddb830081894a44e537  980884799
# 2  5ff17a58830081894a920a90  980944479
# 3  5ff64511830081894a39dce3  981194681
# 4  5fefaddb830081894a44e56e  980874095
#
#                                             location  \
# 0  {'coordinates': [-94.5515029, 39.0454547], 'ty...
# 1  {'coordinates': [-94.57296129999999, 39.013547...
# 2  {'coordinates': [-94.5890969, 39.063922], 'typ...
# 3  {'coordinates': [-94.5956984, 39.040048], 'typ...
# 4  {'coordinates': [-94.54718729999999, 39.046158...
#
#                                   incidentType   parentIncidentType  \
# 0                         Assault (Aggravated)              Assault
# 1                   Burglary (Non-Residential)  Breaking & Entering
# 2  Stealing from Auto (Auto Part or Accessory)   Theft from Vehicle
# 3         Stealing from Auto (Theft from Auto)   Theft from Vehicle
# 4         Obstructing and Resisting an Officer      Quality of Life
#
#    parentIncidentTypeId                       _id
# 0                   149  5fefaddb830081894a44e56a
# 1                   100  5fefaddb830081894a44e537
# 2                   101  5ff17a58830081894a920a90
# 3                   101  5ff64511830081894a39dce3
# 4                    12  5fefaddb830081894a44e56e

# %%
crime_types = pd.DataFrame(crime_df['parentIncidentType'].value_counts())
crime_types.rename(columns = {'parentIncidentType': 'Incident Type'})
# Out:
#                      Incident Type
# Assault                       3526
# Theft                         2915
# Theft from Vehicle            2219
# Property Crime                1641
# Theft of Vehicle              1504
# Quality of Life               1127
# Breaking & Entering            990
# Robbery                        434
# Assault                        395
# Property Crime                 225
# Sexual Offense                 199
# Homicide                        24
# Other ;Homicide                  1
