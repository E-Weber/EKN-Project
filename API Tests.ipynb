# %%
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress

# %%
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload = '{"limit":2000,"offset":0,"geoJson":{"type":"Polygon","coordinates":[[[-94.32951884471989,38.996363264325836],[-94.64880900585229,38.996363264325836],[-94.64880900585229,39.080896419140764],[-94.32951884471989,39.080896419140764],[-94.32951884471989,38.996363264325836]]]},"projection":true,"propertyMap":{"toDate":"2020-12-11T23:59:59.999Z","fromDate":"2020-12-08T00:00:00.000Z","pageSize":"2000","parentIncidentTypeIds":"149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15","zoomLevel":"12","latitude":"39.03864248355025","longitude":"-94.48916392528609","days":"1,2,3,4,5,6,7","startHour":"0","endHour":"24","timezone":"+00:00","relativeDate":"custom","agencyIds":"47860,1279,957,165,118,undefined,undefined"}}'
response = requests.request("POST", url, data=payload, headers=headers)
print(json.dumps(response.json(), indent=2))

# %%
payload = {}
from_date = "2020-3-1T00:00:00.000Z"
to_date = "2020-12-31T23:59:59.999Z"
pageSize = "100000"
payload["limit"] = pageSize
payload["offset"] = 0
payload["geoJson"] = {"type": "Polygon", "coordinates": [[[-94.32951884471989, 38.996363264325836], [-94.64880900585229, 38.996363264325836], [-94.64880900585229, 39.080896419140764], [-94.32951884471989, 39.080896419140764], [-94.32951884471989, 38.996363264325836]]]}
payload["projection"]= "true"
payload["propertyMap"] = {"toDate": to_date, "fromDate": from_date, "pageSize": pageSize, "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15", "zoomLevel": "12", "latitude": "39.03864248355025", "longitude": "-94.48916392528609", "days": "1,2,3,4,5,6,7", "startHour": "0", "endHour": "24", "timezone": "+00:00", "relativeDate": "custom", "agencyIds": "47860,1279,957,165,118,undefined,undefined"}
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload  = json.dumps(payload)
response = requests.request("POST", url, data=payload, headers=headers)
print(len(response.json()['result']['list']['incidents']))
# Out:
# 15202

# %%
crime_df = pd.DataFrame(response.json()['result']['list']['incidents'])
crime_df.head()
# Out:
#                          id    crapiId  \
# 0  5f9f4851562677391ab3b5e4  976864473
# 1  5fa099ba562677391ae66ce0  976869125
# 2  5fa099ba562677391ae66b9b  976934561
# 3  5fa099ba562677391ae66bdd  976925403
# 4  5fac6f69562677391a9eb2bb  977555295
#
#                                             location  \
# 0  {'coordinates': [-94.5577481, 39.0566679], 'ty...
# 1  {'coordinates': [-94.4557171, 39.0470678], 'ty...
# 2  {'coordinates': [-94.5871706, 39.0495085], 'ty...
# 3  {'coordinates': [-94.59226079999999, 39.052619...
# 4  {'coordinates': [-94.59229619999999, 39.052447...
#
#                                         incidentType parentIncidentType  \
# 0         Domestic Violence Assault (Non-Aggravated)           Assault
# 1                                        Stolen Auto   Theft of Vehicle
# 2                           Assault (Non-Aggravated)           Assault
# 3                               Assault (Aggravated)           Assault
# 4  Fraud / Stealing Through Deceit (Scam/Confiden...              Theft
#
#    parentIncidentTypeId                       _id
# 0                   149  5f9f4851562677391ab3b5e4
# 1                    99  5fa099ba562677391ae66ce0
# 2                   149  5fa099ba562677391ae66b9b
# 3                   149  5fa099ba562677391ae66bdd
# 4                   103  5fac6f69562677391a9eb2bb

# %%
crime_types = pd.DataFrame(crime_df['parentIncidentType'].value_counts())
crime_types.rename(columns = {'parentIncidentType': 'Incident Type'})
# Out:
#                      Incident Type
# Assault                       3287
# Theft                         2413
# Theft from Vehicle            1734
# Property Crime                1526
# Theft of Vehicle              1192
# Quality of Life                975
# Breaking & Entering            785
# Robbery                        362
# Sexual Offense                 179
# Homicide                        21
# Property Crime                   5
# Assault                          4
# Other ;Homicide                  1

# %%
payload = {}
from_date = "2019-10-1T00:00:00.000Z"
to_date = "2019-12-31T23:59:59.999Z"
pageSize = "100000"
payload["limit"] = pageSize
payload["offset"] = 0
payload["geoJson"] = {"type": "Polygon", "coordinates": [[[-94.32951884471989, 38.996363264325836], [-94.64880900585229, 38.996363264325836], [-94.64880900585229, 39.080896419140764], [-94.32951884471989, 39.080896419140764], [-94.32951884471989, 38.996363264325836]]]}
payload["projection"]= "true"
payload["propertyMap"] = {"toDate": to_date, "fromDate": from_date, "pageSize": pageSize, "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15", "zoomLevel": "12", "latitude": "39.03864248355025", "longitude": "-94.48916392528609", "days": "1,2,3,4,5,6,7", "startHour": "0", "endHour": "24", "timezone": "+00:00", "relativeDate": "custom", "agencyIds": "47860,1279,957,165,118,undefined,undefined"}
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload  = json.dumps(payload)
response = requests.request("POST", url, data=payload, headers=headers)
print(len(response.json()['result']['list']['incidents']))
# Out:
# 133

# %%
crime_df_2019 = pd.DataFrame(response.json()['result']['list']['incidents'])
crime_df_2019
# Out:
#                            id    crapiId  \
# 0    602d954b147328d61d214d01  984018676
# 1    5e5eebd5844a0f7d1b6e1a42  957137830
# 2    5eeff0fcf85c204ab9443175  965460024
# 3    5edc2a61b8d60951282c0fd5  964380191
# 4    5e5eebd5844a0f7d1b6e1da5  957136731
# ..                        ...        ...
# 128  5f20b937692970560973fa1e  968327259
# 129  5f98ad3933b10f5e73efec92  976544678
# 130  5f84ea7033b10f5e7312d75b  975622651
# 131  5ef9cd982d42b75710ebd71f  965832902
# 132  5e6ebdf81487789a903a4dfb  958174163
#
#                                               location  \
# 0    {'coordinates': [-94.5679334, 39.0341169], 'ty...
# 1    {'coordinates': [-94.5017079, 39.0337503], 'ty...
# 2    {'coordinates': [-94.55615910000002, 39.012503...
# 3    {'coordinates': [-94.56157619999999, 39.001613...
# 4    {'coordinates': [-94.5936419, 39.0117207], 'ty...
# ..                                                 ...
# 128  {'coordinates': [-94.5233277, 39.0532726], 'ty...
# 129  {'coordinates': [-94.572921, 39.0127771], 'typ...
# 130  {'coordinates': [-94.5792695, 39.0650472], 'ty...
# 131  {'coordinates': [-94.53482559999999, 39.017289...
# 132  {'coordinates': [-94.539498, 39.0028797], 'typ...
#
#                                     incidentType  parentIncidentType  \
# 0                               Stealing - Other               Theft
# 1                               Stealing - Other               Theft
# 2    Stealing from Auto (Auto Part or Accessory)  Theft from Vehicle
# 3                                    Stolen Auto    Theft of Vehicle
# 4                          Stealing - Pickpocket               Theft
# ..                                           ...                 ...
# 128                               Identity Theft               Theft
# 129                          Stealing - Shoplift               Theft
# 130   Domestic Violence Assault (Non-Aggravated)            Assault
# 131                                  Stolen Auto    Theft of Vehicle
# 132                                  Molestation      Sexual Offense
#
#      parentIncidentTypeId                       _id
# 0                     103  602d954b147328d61d214d01
# 1                     103  5e5eebd5844a0f7d1b6e1a42
# 2                     101  5eeff0fcf85c204ab9443175
# 3                      99  5edc2a61b8d60951282c0fd5
# 4                     103  5e5eebd5844a0f7d1b6e1da5
# ..                    ...                       ...
# 128                   103  5f20b937692970560973fa1e
# 129                   103  5f98ad3933b10f5e73efec92
# 130                   149  5f84ea7033b10f5e7312d75b
# 131                    99  5ef9cd982d42b75710ebd71f
# 132                     8  5e6ebdf81487789a903a4dfb
#
# [133 rows x 7 columns]

# %%
payload = {}
from_date = "2020-1-1T00:00:00.000Z"
to_date = "2020-10-31T23:59:59.999Z"
pageSize = "100000"
payload["limit"] = pageSize
payload["offset"] = 0
payload["geoJson"] = {"type": "Polygon", "coordinates": [[[-94.32951884471989, 38.996363264325836], [-94.64880900585229, 38.996363264325836], [-94.64880900585229, 39.080896419140764], [-94.32951884471989, 39.080896419140764], [-94.32951884471989, 38.996363264325836]]]}
payload["projection"]= "true"
payload["propertyMap"] = {"toDate": to_date, "fromDate": from_date, "pageSize": pageSize, "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15", "zoomLevel": "12", "latitude": "39.03864248355025", "longitude": "-94.48916392528609", "days": "1,2,3,4,5,6,7", "startHour": "0", "endHour": "24", "timezone": "+00:00", "relativeDate": "custom", "agencyIds": "47860,1279,957,165,118,undefined,undefined"}
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload  = json.dumps(payload)
response = requests.request("POST", url, data=payload, headers=headers)
print(len(response.json()['result']['list']['incidents']))
# Out:
# 12484

# %%
crime_df_2020_pre = pd.DataFrame(response.json()['result']['list']['incidents'])
crime_df_2020_pre
# Out:
#                              id    crapiId  \
# 0      5f9f4851562677391ab3b5e4  976864473
# 1      5fa099ba562677391ae66ce0  976869125
# 2      5fa099ba562677391ae66b9b  976934561
# 3      5fa099ba562677391ae66bdd  976925403
# 4      5fac6f69562677391a9eb2bb  977555295
# ...                         ...        ...
# 12479  5f20b937692970560973fa1e  968327259
# 12480  5f98ad3933b10f5e73efec92  976544678
# 12481  5f84ea7033b10f5e7312d75b  975622651
# 12482  5ef9cd982d42b75710ebd71f  965832902
# 12483  5e6ebdf81487789a903a4dfb  958174163
#
#                                                 location  \
# 0      {'coordinates': [-94.5577481, 39.0566679], 'ty...
# 1      {'coordinates': [-94.4557171, 39.0470678], 'ty...
# 2      {'coordinates': [-94.5871706, 39.0495085], 'ty...
# 3      {'coordinates': [-94.59226079999999, 39.052619...
# 4      {'coordinates': [-94.59229619999999, 39.052447...
# ...                                                  ...
# 12479  {'coordinates': [-94.5233277, 39.0532726], 'ty...
# 12480  {'coordinates': [-94.572921, 39.0127771], 'typ...
# 12481  {'coordinates': [-94.5792695, 39.0650472], 'ty...
# 12482  {'coordinates': [-94.53482559999999, 39.017289...
# 12483  {'coordinates': [-94.539498, 39.0028797], 'typ...
#
#                                             incidentType parentIncidentType  \
# 0             Domestic Violence Assault (Non-Aggravated)           Assault
# 1                                            Stolen Auto   Theft of Vehicle
# 2                               Assault (Non-Aggravated)           Assault
# 3                                   Assault (Aggravated)           Assault
# 4      Fraud / Stealing Through Deceit (Scam/Confiden...              Theft
# ...                                                  ...                ...
# 12479                                     Identity Theft              Theft
# 12480                                Stealing - Shoplift              Theft
# 12481         Domestic Violence Assault (Non-Aggravated)           Assault
# 12482                                        Stolen Auto   Theft of Vehicle
# 12483                                        Molestation     Sexual Offense
#
#        parentIncidentTypeId                       _id
# 0                       149  5f9f4851562677391ab3b5e4
# 1                        99  5fa099ba562677391ae66ce0
# 2                       149  5fa099ba562677391ae66b9b
# 3                       149  5fa099ba562677391ae66bdd
# 4                       103  5fac6f69562677391a9eb2bb
# ...                     ...                       ...
# 12479                   103  5f20b937692970560973fa1e
# 12480                   103  5f98ad3933b10f5e73efec92
# 12481                   149  5f84ea7033b10f5e7312d75b
# 12482                    99  5ef9cd982d42b75710ebd71f
# 12483                     8  5e6ebdf81487789a903a4dfb
#
# [12484 rows x 7 columns]

# %%
payload = {}
from_date = "2020-10-31T00:00:00.000Z"
to_date = "2020-12-31T23:59:59.999Z"
pageSize = "100000"
payload["limit"] = pageSize
payload["offset"] = 0
payload["geoJson"] = {"type": "Polygon", "coordinates": [[[-94.32951884471989, 38.996363264325836], [-94.64880900585229, 38.996363264325836], [-94.64880900585229, 39.080896419140764], [-94.32951884471989, 39.080896419140764], [-94.32951884471989, 38.996363264325836]]]}
payload["projection"]= "true"
payload["propertyMap"] = {"toDate": to_date, "fromDate": from_date, "pageSize": pageSize, "parentIncidentTypeIds": "149,150,148,8,97,104,165,98,100,179,178,180,101,99,103,163,168,166,12,161,14,16,15", "zoomLevel": "12", "latitude": "39.03864248355025", "longitude": "-94.48916392528609", "days": "1,2,3,4,5,6,7", "startHour": "0", "endHour": "24", "timezone": "+00:00", "relativeDate": "custom", "agencyIds": "47860,1279,957,165,118,undefined,undefined"}
url = "https://ce-portal-service.commandcentral.com/api/v1.0/public/incidents"
headers = {'Content-Type': 'application/json'}
payload  = json.dumps(payload)
response = requests.request("POST", url, data=payload, headers=headers)
print(len(response.json()['result']['list']['incidents']))
# Out:
# 2767

# %%
crime_df_2020_post = pd.DataFrame(response.json()['result']['list']['incidents'])
crime_df_2020_post
# Out:
#                             id    crapiId  \
# 0     5fefaddb830081894a44e56a  980874097
# 1     5fefaddb830081894a44e537  980884799
# 2     5ff17a58830081894a920a90  980944479
# 3     5ff64511830081894a39dce3  981194681
# 4     5fefaddb830081894a44e56e  980874095
# ...                        ...        ...
# 2762  5fa099ba562677391ae66cc8  976872465
# 2763  5f9df04d562677391a80da0e  976806328
# 2764  5f9f4851562677391ab3b5da  976868532
# 2765  5f9f4851562677391ab3b690  976824177
# 2766  5f9df04d562677391a80da04  976807575
#
#                                                location  \
# 0     {'coordinates': [-94.5515029, 39.0454547], 'ty...
# 1     {'coordinates': [-94.57296129999999, 39.013547...
# 2     {'coordinates': [-94.5890969, 39.063922], 'typ...
# 3     {'coordinates': [-94.5956984, 39.040048], 'typ...
# 4     {'coordinates': [-94.54718729999999, 39.046158...
# ...                                                 ...
# 2762  {'coordinates': [-94.5808368, 39.0518589], 'ty...
# 2763  {'coordinates': [-94.5024727, 39.0316482], 'ty...
# 2764  {'coordinates': [-94.6021567, 39.039464], 'typ...
# 2765  {'coordinates': [-94.3921321, 39.0321886], 'ty...
# 2766  {'coordinates': [-94.5638421, 39.0055887], 'ty...
#
#                                      incidentType   parentIncidentType  \
# 0                            Assault (Aggravated)              Assault
# 1                      Burglary (Non-Residential)  Breaking & Entering
# 2     Stealing from Auto (Auto Part or Accessory)   Theft from Vehicle
# 3            Stealing from Auto (Theft from Auto)   Theft from Vehicle
# 4            Obstructing and Resisting an Officer      Quality of Life
# ...                                           ...                  ...
# 2762  Stealing from Auto (Auto Part or Accessory)   Theft from Vehicle
# 2763                     Assault (Non-Aggravated)             Assault
# 2764                                  Stolen Auto     Theft of Vehicle
# 2765         Stealing from Auto (Theft from Auto)   Theft from Vehicle
# 2766                         Assault (Aggravated)             Assault
#
#       parentIncidentTypeId                       _id
# 0                      149  5fefaddb830081894a44e56a
# 1                      100  5fefaddb830081894a44e537
# 2                      101  5ff17a58830081894a920a90
# 3                      101  5ff64511830081894a39dce3
# 4                       12  5fefaddb830081894a44e56e
# ...                    ...                       ...
# 2762                   101  5fa099ba562677391ae66cc8
# 2763                   149  5f9df04d562677391a80da0e
# 2764                    99  5f9f4851562677391ab3b5da
# 2765                   101  5f9f4851562677391ab3b690
# 2766                   149  5f9df04d562677391a80da04
#
# [2767 rows x 7 columns]
